# %% [markdown]
# # Análise por Repositório

# %% [markdown]
# Importação do repositório

# %%
import repository as repo

# %% [markdown]
# ## Usuário
#
# Defina o usuário do github que deseja realizar analizar

# %%
# defina o usuário aqui!
user = "gsdenys"

# %% [markdown]
# ## Criação de Repositórios

# %%
repo.printCreationByYear(user)

# %%
repo.getRepos(user)
# Out:
#                         name   fork                created_at  \
# 0          alf-db-constraint  False 2016-01-29 01:27:23+00:00
# 1       alfresco-bulk-export  False 2015-07-29 00:36:35+00:00
# 2                amqp-client  False 2019-07-16 13:52:44+00:00
# 3                 bpm-engine  False 2020-02-17 18:07:22+00:00
# 4           cmis-java-sample  False 2014-12-04 12:35:44+00:00
# 5       cmis-persistence-api  False 2016-12-13 11:45:29+00:00
# 6      cmis-sample-test-case  False 2016-12-24 13:27:12+00:00
# 7                     config   True 2021-01-05 01:02:55+00:00
# 8              content-store  False 2017-10-30 11:12:57+00:00
# 9       content-store-common  False 2017-08-05 23:47:14+00:00
# 10                  ephesoft  False 2016-12-08 18:42:13+00:00
# 11                  eve-demo   True 2018-10-23 12:48:46+00:00
# 12            eve-sqlalchemy   True 2018-10-23 11:07:58+00:00
# 13   flowable-docker-compose  False 2018-04-12 00:42:41+00:00
# ...
