# %%
import repository as repo

# %%
user = "mspdl"

# %% [markdown]
# # Repositories

# %%
#df = repo.getRepos(user)
#creation_from_year = repo.creationFromYear(df)

# %%
#creation_from_year.plot(kind="area", figsize=(20,10), title="Criação de Repositórios por Linguagem e por Ano")
repo.printCreationByYear(user)
# Out:
# <AxesSubplot:title={'center':'Criação de Repositórios por Linguagem e por Ano'}, xlabel='year'>
