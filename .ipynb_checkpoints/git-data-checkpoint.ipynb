# %%
# import requests
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

import time
import json
import requests
import numpy as np
import pandas as pd

import requests
from requests.auth import HTTPBasicAuth

from github.api import Config

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
conf = Config()

user_path = "{}/user_info_{}.csv".format(conf.getPath(), conf.getUser())
repo_path = "{}/repos_info_{}.csv".format(conf.getPath(), conf.getUser())
comm_path = "{}/commits_info_{}.csv".format(conf.getPath(), conf.getUser())


# token = "your-token"

# headers = requests.utils.default_headers()
# headers.update(
#     {
#         'User-Agent': 'PosterisIT',
#         'Authorization': 'token ' + token
#     }
# )

# %%
# data = requests.get('https://api.github.com/users/Oraci', headers=headers)
# data = data.json()
# data

# %%
# print("Name: {}".format(data['name']))
# print("Email: {}".format(data['email']))
# print("Location: {}".format(data['location']))
# print("Public repos: {}".format(data['public_repos']))
# print("Public gists: {}".format(data['public_gists']))
# print("About: {}".format(data['bio']))

# %%
# #iterate over alll repositories
# url = data['repos_url']
# page_no = 1
# repos_data = []

# while (True):
#     response = requests.get(url, headers=headers)
#     response = response.json()
#     repos_data = repos_data + response
#     repos_fetched = len(response)
#     print("Total repositories fetched: {}".format(repos_fetched))
#     if (repos_fetched == 30):
#         page_no = page_no + 1
#         url = data['repos_url'] + '?page=' + str(page_no)
#     else:
#         break

# %%
# repos_information = []
# for i, repo in enumerate(repos_data):
#     data = []
#     data.append(repo['id'])
#     data.append(repo['name'])
#     data.append(repo['description'])
#     data.append(repo['created_at'])
#     data.append(repo['updated_at'])
#     data.append(repo['owner']['login'])
#     data.append(repo['license']['name'] if repo['license'] != None else None)
#     data.append(repo['has_wiki'])
#     data.append(repo['forks_count'])
#     data.append(repo['open_issues_count'])
#     data.append(repo['stargazers_count'])
#     data.append(repo['watchers_count'])
#     data.append(repo['url'])
#     data.append(repo['commits_url'].split("{")[0])
#     data.append(repo['url'] + '/languages')
#     repos_information.append(data)

# %%
# repos_df = pd.DataFrame(repos_information, columns = ['Id', 'Name', 'Description', 'Created on', 'Updated on', 
#                                                       'Owner', 'License', 'Includes wiki', 'Forks count', 
#                                                       'Issues count', 'Stars count', 'Watchers count',
#                                                       'Repo URL', 'Commits URL', 'Languages URL'])

# %%
# for i in range(repos_df.shape[0]):
# #     time.sleep(2)
#     response = requests.get(repos_df.loc[i, 'Languages URL'], headers=headers)
#     response = response.json()
# #     print(i, response)
#     if response != {}:
#         languages = []
#         for key, value in response.items():
#             languages.append(key)
#         languages = ', '.join(languages)
#         repos_df.loc[i, 'Languages'] = languages
#     else:
#         repos_df.loc[i, 'Languages'] = ""
        
# repos_df.to_csv('repos_info.csv', index = False)

# %%
user_df = pd.read_csv(user_path)
repos_df = pd.read_csv(repo_path)
commits_df = pd.read_csv(comm_path)
# Out:
#            Id                     Name  \
# 0    50627775        alf-db-constraint
# 1    39864719     alfresco-bulk-export
# 2   197203698              amqp-client
# 3   241175035               bpm-engine
# 4    27539722         cmis-java-sample
# 5    76353813     cmis-persistence-api
# 6    77284208    cmis-sample-test-case
# 7   326848081                   config
# 8   108839965            content-store
# 9    99453822     content-store-common
# 10   75965279                 ephesoft
# 11  154326988                 eve-demo
# 12  154313637           eve-sqlalchemy
# 13  129171128  flowable-docker-compose
# 14  258924911  francais-et-technologie
# 15  329178172                 git-stat
# 16  334557756          go-plugin-hello
# 17  279911600                  gsdenys
# 18  195415047                hello-lua
# 19   76755134        junit-server-cmis
# 20  194285506         kong-plugin-amqp
# 21  194467967              lua-vagrant
# 22  180455220               nginx-amqp
# 23  276481216      node-module-example
# 24  291313058                npm-badge
# 25  327499857    openresty-lua-example
# 26  327755530     openresty-rabbit-rpc
# 27  146217516             PiggyMetrics
# 28  326178332                 template
# 29  327976915               test-react
# 30  152341182                    teste
#
#                                           Description            Created on  \
# 0       Database constraint to Alfresco Document Type  2016-01-29T01:27:23Z
# 1   Automatically exported from code.google.com/p/...  2015-07-29T00:36:35Z
# 2                                 Lua Client for AMQP  2019-07-16T13:52:44Z
# 3                         Event drive engine for BPMN  2020-02-17T18:07:22Z
# 4              Breve exemplo de ações usando OpenCMIS  2014-12-04T12:35:44Z
# 5   The CMIS Persistence API to help java programe...  2016-12-13T11:45:29Z
# 6    A simple test using JUnit Runner for CMIS Server  2016-12-24T13:27:12Z
# 7                               Configuration Library  2021-01-05T01:02:55Z
# 8                                        First commit  2017-10-30T11:12:57Z
# 9   The API to help implement content persistence ...  2017-08-05T23:47:14Z
# 10          Docker project to create a ephesoft image  2016-12-08T18:42:13Z
# 11   A fully functional REST Web API. Powered by Eve.  2018-10-23T12:48:46Z
# 12  SQLAlchemy data layer for Eve-powered RESTful ...  2018-10-23T11:07:58Z
# 13          A docker compose to flowable and postgres  2018-04-12T00:42:41Z
# 14  Une page html pour enseigner la programmation ...  2020-04-26T02:54:42Z
# 15                                                NaN  2021-01-13T03:05:37Z
# 16                                                NaN  2021-01-31T02:40:29Z
# 17                                                NaN  2020-07-15T15:52:24Z
# 18     A demo of how to make simple C modules for Lua  2019-07-05T13:35:17Z
# 19                       JUnit Runner for CMIS Server  2016-12-18T00:37:53Z
# 20      Kong Plugin to post directly on AMQP exchange  2019-06-28T14:17:30Z
# 21                    Vagrant for lua dev environment  2019-06-30T02:46:28Z
# 22                                                NaN  2019-04-09T21:56:20Z
# 23                         Just a node module example  2020-07-01T21:02:21Z
# 24                   Add badges to your GitHub readme  2020-08-29T17:02:32Z
# 25  An Openresty and Lua in a docker container usa...  2021-01-07T04:10:44Z
# 26                                                NaN  2021-01-08T00:17:14Z
# 27  Microservice Architecture with Spring Boot, Sp...  2018-08-26T21:24:19Z
# 28                       Template for new Probot apps  2021-01-02T12:29:43Z
# 29                     Teste de conhecimento em React  2021-01-08T18:03:42Z
# 30                                                NaN  2018-10-10T00:53:44Z
#
#               Updated on    Owner                                 License  \
# 0   2017-08-09T11:32:25Z  gsdenys  GNU Lesser General Public License v2.1
# 1   2019-09-19T11:17:25Z  gsdenys  GNU Lesser General Public License v3.0
# 2   2020-09-27T09:41:13Z  gsdenys                      Apache License 2.0
# 3   2020-02-17T18:23:29Z  gsdenys                      Apache License 2.0
# 4   2015-03-23T14:09:08Z  gsdenys                                     NaN
# 5   2016-12-13T11:49:08Z  gsdenys                      Apache License 2.0
# 6   2016-12-24T13:27:31Z  gsdenys                      Apache License 2.0
# 7   2021-01-05T01:02:57Z  gsdenys                      Apache License 2.0
# 8   2017-10-30T11:13:56Z  gsdenys                      Apache License 2.0
# 9   2017-11-28T16:25:12Z  gsdenys                      Apache License 2.0
# 10  2020-03-24T19:06:19Z  gsdenys  GNU Affero General Public License v3.0
# 11  2018-10-23T12:48:48Z  gsdenys                                   Other
# 12  2018-10-23T11:08:00Z  gsdenys                                   Other
# 13  2019-02-27T06:32:56Z  gsdenys                      Apache License 2.0
# 14  2020-04-27T12:17:26Z  gsdenys                      Apache License 2.0
# 15  2021-02-08T17:23:22Z  gsdenys                                     NaN
# 16  2021-01-31T02:43:34Z  gsdenys                                     NaN
# 17  2020-12-02T20:17:02Z  gsdenys                                     NaN
# 18  2019-07-05T13:35:19Z  gsdenys                                     NaN
# 19  2018-05-22T09:33:54Z  gsdenys                      Apache License 2.0
# 20  2020-11-11T09:30:06Z  gsdenys                      Apache License 2.0
# 21  2019-07-20T21:46:33Z  gsdenys                      Apache License 2.0
# 22  2019-04-09T21:56:22Z  gsdenys                                     NaN
# 23  2020-07-01T21:07:33Z  gsdenys                                     NaN
# 24  2020-08-29T17:02:35Z  gsdenys                                     NaN
# 25  2021-01-07T16:44:22Z  gsdenys                                     NaN
# 26  2021-01-08T03:29:46Z  gsdenys                                     NaN
# 27  2018-08-26T21:24:21Z  gsdenys                             MIT License
# 28  2021-01-02T12:29:45Z  gsdenys                             ISC License
# 29  2021-01-08T18:03:43Z  gsdenys                                     NaN
# 30  2018-10-12T01:17:54Z  gsdenys                      Apache License 2.0
#
#     Includes wiki  Forks count  Issues count  Stars count  Watchers count  \
# 0            True            0             0            4               4
# 1           False           32            17           11              11
# 2            True            7             6            5               5
# 3            True            0             0            0               0
# 4            True            0             0            1               1
# 5            True            0             0            0               0
# 6            True            0             0            0               0
# 7            True            0             0            0               0
# 8            True            0             0            0               0
# 9            True            0             0            0               0
# 10          False            7            10            3               3
# 11          False            0             0            0               0
# 12           True            0             0            0               0
# 13           True            1             0            1               1
# 14           True            0             0            0               0
# 15           True            0             0            0               0
# 16           True            0             0            0               0
# 17           True            0             0            0               0
# 18           True            0             0            0               0
# 19          False            1             4            1               1
# 20           True            4             4            3               3
# 21           True            0             0            0               0
# 22           True            0             0            0               0
# 23           True            0             0            0               0
# 24           True            0             0            0               0
# 25           True            0             0            0               0
# 26           True            0             0            0               0
# 27          False            0             0            0               0
# 28           True            0             0            0               0
# 29           True            0             0            0               0
# 30           True            0             0            0               0
#
#                                              Repo URL  \
# 0   https://api.github.com/repos/gsdenys/alf-db-co...
# 1   https://api.github.com/repos/gsdenys/alfresco-...
# 2    https://api.github.com/repos/gsdenys/amqp-client
# 3     https://api.github.com/repos/gsdenys/bpm-engine
# 4   https://api.github.com/repos/gsdenys/cmis-java...
# 5   https://api.github.com/repos/gsdenys/cmis-pers...
# 6   https://api.github.com/repos/gsdenys/cmis-samp...
# 7         https://api.github.com/repos/gsdenys/config
# 8   https://api.github.com/repos/gsdenys/content-s...
# 9   https://api.github.com/repos/gsdenys/content-s...
# 10      https://api.github.com/repos/gsdenys/ephesoft
# 11      https://api.github.com/repos/gsdenys/eve-demo
# 12  https://api.github.com/repos/gsdenys/eve-sqlal...
# 13  https://api.github.com/repos/gsdenys/flowable-...
# 14  https://api.github.com/repos/gsdenys/francais-...
# 15      https://api.github.com/repos/gsdenys/git-stat
# 16  https://api.github.com/repos/gsdenys/go-plugin...
# 17       https://api.github.com/repos/gsdenys/gsdenys
# 18     https://api.github.com/repos/gsdenys/hello-lua
# 19  https://api.github.com/repos/gsdenys/junit-ser...
# 20  https://api.github.com/repos/gsdenys/kong-plug...
# 21   https://api.github.com/repos/gsdenys/lua-vagrant
# 22    https://api.github.com/repos/gsdenys/nginx-amqp
# 23  https://api.github.com/repos/gsdenys/node-modu...
# 24     https://api.github.com/repos/gsdenys/npm-badge
# 25  https://api.github.com/repos/gsdenys/openresty...
# 26  https://api.github.com/repos/gsdenys/openresty...
# 27  https://api.github.com/repos/gsdenys/PiggyMetrics
# 28      https://api.github.com/repos/gsdenys/template
# 29    https://api.github.com/repos/gsdenys/test-react
# 30         https://api.github.com/repos/gsdenys/teste
#
#                                           Commits URL  \
# 0   https://api.github.com/repos/gsdenys/alf-db-co...
# 1   https://api.github.com/repos/gsdenys/alfresco-...
# 2   https://api.github.com/repos/gsdenys/amqp-clie...
# 3   https://api.github.com/repos/gsdenys/bpm-engin...
# 4   https://api.github.com/repos/gsdenys/cmis-java...
# 5   https://api.github.com/repos/gsdenys/cmis-pers...
# 6   https://api.github.com/repos/gsdenys/cmis-samp...
# 7   https://api.github.com/repos/gsdenys/config/co...
# 8   https://api.github.com/repos/gsdenys/content-s...
# 9   https://api.github.com/repos/gsdenys/content-s...
# 10  https://api.github.com/repos/gsdenys/ephesoft/...
# 11  https://api.github.com/repos/gsdenys/eve-demo/...
# 12  https://api.github.com/repos/gsdenys/eve-sqlal...
# 13  https://api.github.com/repos/gsdenys/flowable-...
# 14  https://api.github.com/repos/gsdenys/francais-...
# 15  https://api.github.com/repos/gsdenys/git-stat/...
# 16  https://api.github.com/repos/gsdenys/go-plugin...
# 17  https://api.github.com/repos/gsdenys/gsdenys/c...
# 18  https://api.github.com/repos/gsdenys/hello-lua...
# 19  https://api.github.com/repos/gsdenys/junit-ser...
# 20  https://api.github.com/repos/gsdenys/kong-plug...
# 21  https://api.github.com/repos/gsdenys/lua-vagra...
# 22  https://api.github.com/repos/gsdenys/nginx-amq...
# 23  https://api.github.com/repos/gsdenys/node-modu...
# 24  https://api.github.com/repos/gsdenys/npm-badge...
# 25  https://api.github.com/repos/gsdenys/openresty...
# 26  https://api.github.com/repos/gsdenys/openresty...
# 27  https://api.github.com/repos/gsdenys/PiggyMetr...
# 28  https://api.github.com/repos/gsdenys/template/...
# 29  https://api.github.com/repos/gsdenys/test-reac...
# 30  https://api.github.com/repos/gsdenys/teste/com...
#
#                                         Languages URL
# 0   https://api.github.com/repos/gsdenys/alf-db-co...
# 1   https://api.github.com/repos/gsdenys/alfresco-...
# 2   https://api.github.com/repos/gsdenys/amqp-clie...
# 3   https://api.github.com/repos/gsdenys/bpm-engin...
# 4   https://api.github.com/repos/gsdenys/cmis-java...
# 5   https://api.github.com/repos/gsdenys/cmis-pers...
# 6   https://api.github.com/repos/gsdenys/cmis-samp...
# 7   https://api.github.com/repos/gsdenys/config/la...
# 8   https://api.github.com/repos/gsdenys/content-s...
# 9   https://api.github.com/repos/gsdenys/content-s...
# 10  https://api.github.com/repos/gsdenys/ephesoft/...
# 11  https://api.github.com/repos/gsdenys/eve-demo/...
# 12  https://api.github.com/repos/gsdenys/eve-sqlal...
# 13  https://api.github.com/repos/gsdenys/flowable-...
# 14  https://api.github.com/repos/gsdenys/francais-...
# 15  https://api.github.com/repos/gsdenys/git-stat/...
# 16  https://api.github.com/repos/gsdenys/go-plugin...
# 17  https://api.github.com/repos/gsdenys/gsdenys/l...
# 18  https://api.github.com/repos/gsdenys/hello-lua...
# 19  https://api.github.com/repos/gsdenys/junit-ser...
# 20  https://api.github.com/repos/gsdenys/kong-plug...
# 21  https://api.github.com/repos/gsdenys/lua-vagra...
# 22  https://api.github.com/repos/gsdenys/nginx-amq...
# 23  https://api.github.com/repos/gsdenys/node-modu...
# 24  https://api.github.com/repos/gsdenys/npm-badge...
# 25  https://api.github.com/repos/gsdenys/openresty...
# 26  https://api.github.com/repos/gsdenys/openresty...
# 27  https://api.github.com/repos/gsdenys/PiggyMetr...
# 28  https://api.github.com/repos/gsdenys/template/...
# 29  https://api.github.com/repos/gsdenys/test-reac...
# 30  https://api.github.com/repos/gsdenys/teste/lan...

# %%
repos_df.shape[0]

# %% [markdown]
# ### commits

# %%
# commits_information = []
# for i in range(repos_df.shape[0]):
#     url = repos_df.loc[i, 'Commits URL']
#     page_no = 1
#     while (True):
#         response = requests.get(url, headers=headers)
#         response = response.json()
# #         print("URL: {}, commits: {}".format(url, len(response)))
#         for commit in response:
#             commit_data = []
#             commit_data.append(repos_df.loc[i, 'Id'])
#             commit_data.append(commit['sha'])
#             commit_data.append(commit['commit']['committer']['date'])
#             commit_data.append(commit['commit']['message'])
#             commits_information.append(commit_data)
#         if (len(response) == 30):
#             page_no = page_no + 1
#             url = repos_df.loc[i, 'Commits URL'] + '?page=' + str(page_no)
#         else:
#             break
            
# commits_df = pd.DataFrame(commits_information, columns = ['Repo Id', 'Commit Id', 'Date', 'Message'])
# # commits_df.to_csv('commits_info.csv', index = False)

# %% [markdown]
# ## Analisys

# %%
repos = repos_df
commits = commits_df

# %%
print("Total repos till date: {}".format(repos.shape[0]))
print("Total commits till date: {}".format(commits.shape[0]))

# %%
repos.describe()

# %%
print("Two most common commit messages: {}".format(' and '.join(commits['Message'].value_counts().index[:2])))

# %%
commits_count = pd.DataFrame(pd.merge(repos, 
         commits, 
         left_on='Id', 
         right_on='Repo Id', 
         how = 'left').groupby('Id').size().reset_index())
commits_count.columns = ['Id', 'Commits count']

# %%
repos = pd.merge(repos, commits_count, on = 'Id')

# %%
plt.figure(figsize = (20, 12))
sns.barplot(repos['Name'], repos['Commits count'])
plt.xticks(rotation = 90)
plt.xlabel("Repository", fontsize = 16)
plt.ylabel("Commits", fontsize = 16)
plt.title("Commits per repository", fontsize = 16)

# %%
commits['Year'] = commits['Date'].apply(lambda x: x.split('-')[0])
yearly_stats = commits.groupby('Year').count()['Commit Id']

# %%
plt.figure(figsize = (20, 12))
sns.barplot(yearly_stats.index, yearly_stats.values)
plt.xlabel("Year", fontsize = 16)
plt.ylabel("Commits", fontsize = 16)
plt.title("Commits in each year", fontsize = 16)

# %%
commits['Month'] = commits['Date'].apply(lambda x: x.split('-')[1])
monthly_stats = commits[commits['Year'] == '2020'].groupby('Month').count()['Commit Id']

# %%
month_mapper = { '01': 'January', '02': 'February', '03': 'March', '04': 'April', '05': 'May', '06': 'June', '07': 'July', '08': 'Autgust', '09': 'September','10': 'October', '11':'November', '12': 'Dezember'}
labels = []
for value in monthly_stats.index:
    labels.append(month_mapper[value])

plt.figure(figsize = (20, 12))
plot = sns.barplot(monthly_stats.index, monthly_stats.values)
plt.xlabel("Month", fontsize = 16)
plot.set_xticklabels(labels)
plt.ylabel("Commits", fontsize = 16)
plt.title("Commits in each month of 2020", fontsize = 16)

# %%
commits['Date only'] = pd.to_datetime(commits['Date'].apply(lambda date: date.split('T')[0]))
commit_stats = commits[(commits['Year'] == '2020')
                       & (commits['Month'] == '09')]['Date only'].value_counts().sort_index()

# %%
labels = []
for value in commit_stats.index:
    labels.append(value.date())
    
plt.figure(figsize = (20, 12))
plot = sns.barplot(commit_stats.index, commit_stats.values)
plt.xlabel("Date", fontsize = 16)
plt.xticks(rotation = 90)
plot.set_xticklabels(labels)
plt.ylabel("Commits", fontsize = 16)
plt.title("Commits in March, 2019", fontsize = 16)

# %% [markdown]
# ## Language

# %%
list_of_languages = []
for languages in repos['Languages']:
    if type(languages) == str:
        for language in languages.split(','):
            list_of_languages.append(language.strip())

# %%
languages_count = pd.Series(list_of_languages).value_counts()

plt.figure(figsize = (20, 12))
sns.barplot(languages_count.index, languages_count.values)
plt.xlabel("Languages", fontsize = 16)
plt.xticks(rotation = 90)
plt.ylabel("Repositories", fontsize = 16)
plt.title("Language distribution amongst all repositories", fontsize = 16)
